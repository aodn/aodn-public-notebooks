# %% [markdown]
# # Exploring moorings timeseries data in Parquet format with Dask

# %%
import s3fs
s3 = s3fs.S3FileSystem(anon=False)
s3_path = 's3://imos-data-lab-optimised/parquet/timeseries/'
s3.glob(s3_path)
# Out:
# ['imos-data-lab-optimised/parquet/timeseries/site_code=PH100']

# %% [markdown]
# ## Using single-machine scheduler

# %%
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
dask.config.set(scheduler='threads')

# %%
# %%time
df = dd.read_parquet('s3://imos-data-lab-optimised/parquet/timeseries/site_code=PH100/deployment_code=PH100-2112/',
                     columns=['nominal_depth', 'temp', 'temp_quality_control', 'depth', 'depth_quality_control'],
                     index='time'
                     )
df
# Out:
# CPU times: user 232 ms, sys: 8.13 ms, total: 240 ms
# Wall time: 828 ms
# Dask DataFrame Structure:
#                nominal_depth     temp temp_quality_control    depth depth_quality_control
# npartitions=15
#                      float32  float32              float32  float32               float32
#                          ...      ...                  ...      ...                   ...
# ...                      ...      ...                  ...      ...                   ...
#                          ...      ...                  ...      ...                   ...
#                          ...      ...                  ...      ...                   ...
# Dask Name: read-parquet, 15 tasks

# %%
# %%time
print(len(df), df.npartitions)
# Out:
# 436153 15
# CPU times: user 287 ms, sys: 10.2 ms, total: 297 ms
# Wall time: 457 ms

# %%
# %%time
df.head(100_000, npartitions=-1)
# Out:
# CPU times: user 380 ms, sys: 41.3 ms, total: 421 ms
# Wall time: 683 ms
#                                nominal_depth       temp  temp_quality_control  \
# time
# 2021-12-14 19:00:01.000001280           16.0  17.043800                   4.0
# 2021-12-14 19:05:01.000003584           16.0  16.990700                   4.0
# 2021-12-14 19:10:01.000005632           16.0  16.969101                   4.0
# 2021-12-14 19:15:00.999997952           16.0  16.978201                   4.0
# 2021-12-14 19:20:01.000000256           16.0  17.001699                   4.0
# ...                                      ...        ...                   ...
# 2022-01-20 11:55:00.000007936           32.0  22.022560                   1.0
# 2022-01-20 12:00:00.000000000           32.0  21.992298                   1.0
# 2022-01-20 12:05:00.000002304           32.0  21.975014                   1.0
# 2022-01-20 12:10:00.000004352           32.0  21.987978                   1.0
# 2022-01-20 12:15:00.000006656           32.0  21.962053                   1.0
#
#                                    depth  depth_quality_control
# time
# 2021-12-14 19:00:01.000001280   0.138000                    4.0
# 2021-12-14 19:05:01.000003584   0.140000                    4.0
# 2021-12-14 19:10:01.000005632   0.141000                    4.0
# 2021-12-14 19:15:00.999997952   0.143000                    4.0
# 2021-12-14 19:20:01.000000256   0.142000                    4.0
# ...                                  ...                    ...
# 2022-01-20 11:55:00.000007936  32.999931                    1.0
# 2022-01-20 12:00:00.000000000  32.992203                    1.0
# 2022-01-20 12:05:00.000002304  32.989025                    1.0
# 2022-01-20 12:10:00.000004352  32.970432                    1.0
# 2022-01-20 12:15:00.000006656  32.995274                    1.0
#
# [100000 rows x 5 columns]

# %%
# %%time
df.loc['2022-01-01'].compute()
# Out:
# CPU times: user 603 ms, sys: 63.6 ms, total: 666 ms
# Wall time: 1.32 s
#                                nominal_depth       temp  temp_quality_control  \
# time
# 2022-01-01 00:00:01.000004608           16.0  21.090900                   1.0
# 2022-01-01 00:05:00.999996928           16.0  20.712200                   1.0
# 2022-01-01 00:10:00.999998976           16.0  20.772800                   1.0
# 2022-01-01 00:15:01.000001280           16.0  21.026600                   1.0
# 2022-01-01 00:20:01.000003584           16.0  20.889200                   1.0
# ...                                      ...        ...                   ...
# 2022-01-01 23:34:59.999998976           88.0  14.302550                   1.0
# 2022-01-01 23:40:00.000001024           88.0  14.348369                   1.0
# 2022-01-01 23:45:00.000003328           88.0  14.459716                   1.0
# 2022-01-01 23:50:00.000005632           88.0  14.330039                   1.0
# 2022-01-01 23:55:00.000007936           88.0  14.322185                   1.0
#
#                                    depth  depth_quality_control
# time
# 2022-01-01 00:00:01.000004608  17.671000                    1.0
# 2022-01-01 00:05:00.999996928  17.754999                    1.0
# 2022-01-01 00:10:00.999998976  17.629000                    1.0
# 2022-01-01 00:15:01.000001280  17.704000                    1.0
# 2022-01-01 00:20:01.000003584  17.480000                    1.0
# ...                                  ...                    ...
# 2022-01-01 23:34:59.999998976  88.392899                    1.0
# 2022-01-01 23:40:00.000001024  88.372681                    1.0
# 2022-01-01 23:45:00.000003328  88.341156                    1.0
# 2022-01-01 23:50:00.000005632  88.302521                    1.0
# 2022-01-01 23:55:00.000007936  88.269524                    1.0
#
# [4320 rows x 5 columns]

# %%
# %%time
df.loc['2022-01'].compute()
# Out:
# CPU times: user 299 ms, sys: 42 ms, total: 341 ms
# Wall time: 445 ms
#                                nominal_depth       temp  temp_quality_control  \
# time
# 2022-01-01 00:00:01.000004608           16.0  21.090900                   1.0
# 2022-01-01 00:05:00.999996928           16.0  20.712200                   1.0
# 2022-01-01 00:10:00.999998976           16.0  20.772800                   1.0
# 2022-01-01 00:15:01.000001280           16.0  21.026600                   1.0
# 2022-01-01 00:20:01.000003584           16.0  20.889200                   1.0
# ...                                      ...        ...                   ...
# 2022-01-31 23:34:59.999998976           88.0  12.603698                   1.0
# 2022-01-31 23:40:00.000001024           88.0  12.601111                   1.0
# 2022-01-31 23:45:00.000003328           88.0  12.579122                   1.0
# 2022-01-31 23:50:00.000005632           88.0  12.575242                   1.0
# 2022-01-31 23:55:00.000007936           88.0  12.583002                   1.0
#
#                                    depth  depth_quality_control
# time
# 2022-01-01 00:00:01.000004608  17.671000                    1.0
# 2022-01-01 00:05:00.999996928  17.754999                    1.0
# 2022-01-01 00:10:00.999998976  17.629000                    1.0
# 2022-01-01 00:15:01.000001280  17.704000                    1.0
# 2022-01-01 00:20:01.000003584  17.480000                    1.0
# ...                                  ...                    ...
# 2022-01-31 23:34:59.999998976  88.541756                    1.0
# 2022-01-31 23:40:00.000001024  88.523026                    1.0
# 2022-01-31 23:45:00.000003328  88.496277                    1.0
# 2022-01-31 23:50:00.000005632  88.487083                    1.0
# 2022-01-31 23:55:00.000007936  88.446335                    1.0
#
# [133920 rows x 5 columns]

# %%
subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nominal_depth          0 non-null      float32
#  1   time                   0 non-null      datetime64[ns]
#  2   temp                   0 non-null      float32
#  3   temp_quality_control   0 non-null      float32
#  4   depth                  0 non-null      float32
#  5   depth_quality_control  0 non-null      float32
# dtypes: datetime64[ns](1), float32(5)
# memory usage: 124.0 bytes

# %% [markdown]
# ## Using distributed scheduler

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:34859")

# %%
# %%time
import dask.dataframe as dd

df = dd.read_parquet('s3://imos-data-lab-optimised/parquet/timeseries/site_code=PH100/',
                     columns=['nominal_depth', 'time', 'temp', 'temp_quality_control', 'depth', 'depth_quality_control']
                    )
df
# Out:
# CPU times: user 637 ms, sys: 35.2 ms, total: 672 ms
# Wall time: 3.01 s
# Dask DataFrame Structure:
#                 nominal_depth            time     temp temp_quality_control    depth depth_quality_control
# npartitions=832
#                       float32  datetime64[ns]  float32              float32  float32               float32
#                           ...             ...      ...                  ...      ...                   ...
# ...                       ...             ...      ...                  ...      ...                   ...
#                           ...             ...      ...                  ...      ...                   ...
#                           ...             ...      ...                  ...      ...                   ...
# Dask Name: read-parquet, 832 tasks

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 6 entries, nominal_depth to depth_quality_control
# dtypes: datetime64[ns](1), float32(5)

# %%
df.head()
# Out:
#    nominal_depth                          time       temp  \
# 0           32.0 2009-10-28 13:00:00.000006656  18.740826
# 1           32.0 2009-10-28 13:04:59.999998976  18.731161
# 2           32.0 2009-10-28 13:10:00.000001024  18.720119
# 3           32.0 2009-10-28 13:15:00.000003328  18.711840
# 4           32.0 2009-10-28 13:20:00.000005632  18.704939
#
#    temp_quality_control     depth  depth_quality_control
# 0                   4.0  0.226669                    4.0
# 1                   4.0  0.232219                    4.0
# 2                   4.0  0.232219                    4.0
# 3                   4.0  0.232219                    4.0
# 4                   4.0  0.226669                    4.0

# %%
# %%time
import numpy as np
good_rows = np.logical_and(df.temp_quality_control==1,
                           df.depth_quality_control==1)
df_temp = df.loc[good_rows, ['nominal_depth', 'time', 'temp', 'depth']] 
df_temp
# Out:
# CPU times: user 3.45 ms, sys: 4.23 ms, total: 7.68 ms
# Wall time: 6.93 ms
# Dask DataFrame Structure:
#                 nominal_depth            time     temp    depth
# npartitions=832
#                       float32  datetime64[ns]  float32  float32
#                           ...             ...      ...      ...
# ...                       ...             ...      ...      ...
#                           ...             ...      ...      ...
#                           ...             ...      ...      ...
# Dask Name: loc-series, 5824 tasks

# %%
df_temp.head()
# Out:
#      nominal_depth                          time       temp      depth
# 169           32.0 2009-10-29 03:05:00.000002304  18.892847  33.270786
# 170           32.0 2009-10-29 03:10:00.000004352  18.901150  33.320877
# 171           32.0 2009-10-29 03:15:00.000006656  18.906685  33.343143
# 172           32.0 2009-10-29 03:19:59.999998976  18.876247  33.343143
# 173           32.0 2009-10-29 03:25:00.000001024  18.858269  33.320877

# %%
hourly_temp = df_temp.groupby('nominal_depth', group_keys=False) #.resample('1H').mean()
hourly_temp

# %%
df_temp.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 4 entries, nominal_depth to depth
# dtypes: datetime64[ns](1), float32(3)

# %%
# %%time
def hourly_mean(df):
    return df.resample('1H', on='time').mean()

hourly_temp = df_temp.map_partitions(hourly_mean,
                                     meta=df_temp.loc[0, ['nominal_depth', 'temp', 'depth']]
                                    )
hourly_temp
# Out:
# CPU times: user 6.24 ms, sys: 213 µs, total: 6.46 ms
# Wall time: 6.21 ms
# Dask DataFrame Structure:
#                 nominal_depth     temp    depth
# npartitions=832
#                       float32  float32  float32
#                           ...      ...      ...
# ...                       ...      ...      ...
#                           ...      ...      ...
#                           ...      ...      ...
# Dask Name: hourly_mean, 6656 tasks

# %%
hourly_temp.compute()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 hourly_temp.compute()
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/base.py:288, in DaskMethodsMixin.compute(self, **kwargs)
#     264 def compute(self, **kwargs):
#     265     """Compute this dask collection
#     266
#     267     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     286     dask.base.compute
#     287     """
# --> 288     (result,) = compute(self, traverse=False, **kwargs)
#     289     return result
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/base.py:571, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     568     keys.append(x.__dask_keys__())
#     569     postcomputes.append(x.__dask_postcompute__())
# --> 571 results = schedule(dsk, keys, **kwargs)
#     572 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/client.py:2992, in Client.get(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2990         should_rejoin = False
#    2991 try:
# -> 2992     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2993 finally:
#    2994     for f in futures.values():
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/client.py:2144, in Client.gather(self, futures, errors, direct, asynchronous)
#    2142 else:
#    2143     local_worker = None
# -> 2144 return self.sync(
#    2145     self._gather,
#    2146     futures,
#    2147     errors=errors,
#    2148     direct=direct,
#    2149     local_worker=local_worker,
#    2150     asynchronous=asynchronous,
#    2151 )
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/utils.py:309, in SyncMethodMixin.sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     307     return future
#     308 else:
# --> 309     return sync(
#     310         self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     311     )
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/utils.py:363, in sync(loop, func, callback_timeout, *args, **kwargs)
#     361 if error[0]:
#     362     typ, exc, tb = error[0]
# --> 363     raise exc.with_traceback(tb)
#     364 else:
#     365     return result[0]
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/utils.py:348, in sync.<locals>.f()
#     346     if callback_timeout is not None:
#     347         future = asyncio.wait_for(future, callback_timeout)
# --> 348     result[0] = yield future
#     349 except Exception:
#     350     error[0] = sys.exc_info()
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/tornado/gen.py:769, in Runner.run(self)
#     766 exc_info = None
#     768 try:
# --> 769     value = future.result()
#     770 except Exception:
#     771     exc_info = sys.exc_info()
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/distributed/client.py:2007, in Client._gather(self, futures, errors, direct, local_worker)
#    2005         exc = CancelledError(key)
#    2006     else:
# -> 2007         raise exception.with_traceback(traceback)
#    2008     raise exc
#    2009 if errors == "skip":
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/optimization.py:969, in __call__()
#     967 if not len(args) == len(self.inkeys):
#     968     raise ValueError("Expected %d args, got %d" % (len(self.inkeys), len(args)))
# --> 969 return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/core.py:149, in get()
#     147 for key in toposort(dsk):
#     148     task = dsk[key]
# --> 149     result = _execute_task(task, cache)
#     150     cache[key] = result
#     151 result = _execute_task(out, cache)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/core.py:119, in _execute_task()
#     115     func, args = arg[0], arg[1:]
#     116     # Note: Don't assign the subtask results to a variable. numpy detects
#     117     # temporaries by their reference count and can execute certain
#     118     # operations in-place.
# --> 119     return func(*(_execute_task(a, cache) for a in args))
#     120 elif not ishashable(arg):
#     121     return arg
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/dataframe/io/parquet/core.py:87, in __call__()
#      84 if not isinstance(part, list):
#      85     part = [part]
# ---> 87 return read_parquet_part(
#      88     self.fs,
#      89     self.engine,
#      90     self.meta,
#      91     [(p["piece"], p.get("kwargs", {})) for p in part],
#      92     self.columns,
#      93     self.index,
#      94     self.common_kwargs,
#      95 )
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/dataframe/io/parquet/core.py:431, in read_parquet_part()
#     428 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     429     # Part kwargs expected
#     430     func = engine.read_partition
# --> 431     dfs = [
#     432         func(fs, rg, columns.copy(), index, **toolz.merge(kwargs, kw))
#     433         for (rg, kw) in part
#     434     ]
#     435     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     436 else:
#     437     # No part specific kwargs, let engine read
#     438     # list of parts at once
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/dataframe/io/parquet/core.py:432, in <listcomp>()
#     428 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     429     # Part kwargs expected
#     430     func = engine.read_partition
#     431     dfs = [
# --> 432         func(fs, rg, columns.copy(), index, **toolz.merge(kwargs, kw))
#     433         for (rg, kw) in part
#     434     ]
#     435     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     436 else:
#     437     # No part specific kwargs, let engine read
#     438     # list of parts at once
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/dataframe/io/parquet/fastparquet.py:1027, in read_partition()
#    1022     parquet_file._dtypes = (
#    1023         lambda *args: parquet_file.dtypes
#    1024     )  # ugly patch, could be fixed
#    1026     # Convert ParquetFile to pandas
# -> 1027     return cls.pf_to_pandas(
#    1028         parquet_file,
#    1029         fs=fs,
#    1030         columns=columns,
#    1031         categories=categories,
#    1032         index=index,
#    1033         **kwargs.get("read", {}),
#    1034     )
#    1036 else:
#    1037     # `sample` is NOT a tuple
#    1038     raise ValueError(f"Expected tuple, got {type(sample)}")
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/dask/dataframe/io/parquet/fastparquet.py:1067, in pf_to_pandas()
#    1065 rgs = pf.row_groups
#    1066 size = sum(rg.num_rows for rg in rgs)
# -> 1067 df, views = pf.pre_allocate(size, columns, categories, index)
#    1068 start = 0
#    1070 # Get a map of file names -> row-groups
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/fastparquet/api.py:780, in pre_allocate()
#     778 categories = self.check_categories(categories)
#     779 cats = {k: v for k, v in self.cats.items() if k in columns}
# --> 780 df, arrs = _pre_allocate(size, columns, categories, index, cats,
#     781                          self._dtypes(categories), self.tz)
#     782 i_no_name = re.compile(r"__index_level_\d+__")
#     783 if self.has_pandas_metadata:
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/fastparquet/api.py:1014, in _pre_allocate()
#    1011         return "int64"
#    1012     return t
# -> 1014 dtypes = [get_type(c) for c in cols]
#    1015 index_types = [get_type(i, index=True) for i in index]
#    1016 cols.extend(cs)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/fastparquet/api.py:1014, in <listcomp>()
#    1011         return "int64"
#    1012     return t
# -> 1014 dtypes = [get_type(c) for c in cols]
#    1015 index_types = [get_type(i, index=True) for i in index]
#    1016 cols.extend(cs)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/fastparquet/api.py:1009, in get_type()
#    1007 if name in categories:
#    1008     return 'category'
# -> 1009 t = dt[name]
#    1010 if index and isinstance(t, pd.core.arrays.masked.BaseMaskedDtype):
#    1011     return "int64"
#
# KeyError: 'depth'

# %%
import hvplot
import hvplot.dask

# %%
# %%time
hourly_temp.hvplot.scatter(x='time', y='depth', c='temp', cmap='plasma', flip_yaxis=True)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/plotting/core.py:492, in hvPlotTabular.scatter(self, x, y, **kwds)
#     414 def scatter(self, x=None, y=None, **kwds):
#     415     """
#     416     The `scatter` plot visualizes your points as markers in 2D space. You can visualize
#     417     one more dimension by using colors.
#    (...)
#     490     - Wiki: https://en.wikipedia.org/wiki/Scatter_plot
#     491     """
# --> 492     return self(x, y, kind="scatter", **kwds)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/plotting/core.py:130, in hvPlotBase.__call__(self, x, y, kind, **kwds)
#     127         plot = self._get_converter(x, y, kind, **kwds)(kind, x, y)
#     128         return pn.panel(plot, **panel_dict)
# --> 130 return self._get_converter(x, y, kind, **kwds)(kind, x, y)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/converter.py:1228, in HoloViewsConverter.__call__(self, kind, x, y)
#    1226                 dataset = Dataset(data)
#    1227             dataset = dataset.redim(**self._redim)
# -> 1228         obj = method(x, y)
#    1229         obj._dataset = dataset
#    1231 if self.crs and self.project:
#    1232     # Apply projection before rasterizing
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/converter.py:1641, in HoloViewsConverter.scatter(self, x, y, data)
#    1639 def scatter(self, x=None, y=None, data=None):
#    1640     self._error_if_unavailable('scatter')
# -> 1641     return self.chart(Scatter, x, y, data)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/converter.py:1599, in HoloViewsConverter.chart(self, element, x, y, data)
#    1597 data, x, y = self._process_chart_args(data, x, y)
#    1598 if x and y and not isinstance(y, (list, tuple)):
# -> 1599     return self.single_chart(element, x, y, data)
#    1600 elif x and y and len(y) == 1:
#    1601     return self.single_chart(element, x, y[0], data)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/hvplot/converter.py:1521, in HoloViewsConverter.single_chart(self, element, x, y, data)
#    1519     chart = chart.layout() if self.subplots else chart.overlay(sort=False)
#    1520 else:
# -> 1521     chart = element(data, kdims, vdims).relabel(**self._relabel)
#    1522 return (chart.redim(**self._redim)
#    1523         .opts(cur_opts, backend='bokeh')
#    1524         .opts(compat_opts, backend=self._backend_compat))
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/holoviews/element/selection.py:23, in SelectionIndexExpr.__init__(self, *args, **kwargs)
#      22 def __init__(self, *args, **kwargs):
# ---> 23     super().__init__(*args, **kwargs)
#      24     self._index_skip = False
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/holoviews/element/chart.py:51, in Chart.__init__(self, data, kdims, vdims, **params)
#      49 if len(params.get('kdims', [])) == self._max_kdim_count + 1:
#      50     self.param.warning('Chart elements should only be supplied a single kdim')
# ---> 51 super().__init__(data, **params)
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/holoviews/core/data/__init__.py:342, in Dataset.__init__(self, data, kdims, vdims, **kwargs)
#     340 (data, self.interface, dims, extra_kws) = initialized
#     341 super(Dataset, self).__init__(data, **dict(kwargs, **dict(dims, **extra_kws)))
# --> 342 self.interface.validate(self, validate_vdims)
#     344 # Handle _pipeline property
#     345 if input_pipeline is None:
#
# File ~/.pyenv/versions/data-science/lib/python3.8/site-packages/holoviews/core/data/pandas.py:165, in PandasInterface.validate(cls, dataset, vdims)
#     163 not_found = [d for d in dimensions if d not in cols]
#     164 if not_found:
# --> 165     raise DataError("Supplied data does not contain specified "
#     166                     "dimensions, the following dimensions were "
#     167                     "not found: %s" % repr(not_found), cls)
#
# DataError: Supplied data does not contain specified dimensions, the following dimensions were not found: ['time']
#
# DaskInterface expects tabular data, for more information on supported datatypes see http://holoviews.org/user_guide/Tabular_Datasets.html
