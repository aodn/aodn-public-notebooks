# %%
import xarray as xr
import s3fs

# %%
sst_path = "s3://imos-data-pixeldrill/alexstest/"

s3 = s3fs.S3FileSystem(anon=True)
data = xr.open_dataset(s3fs.S3Map(sst_path, s3=s3), engine="zarr")
data
# Out:
# <xarray.Dataset>
# Dimensions:                            (time: 1, lat: 4500, lon: 6000)
# Coordinates:
#   * lat                                (lat) float32 19.99 19.97 ... -69.99
#   * lon                                (lon) float32 70.01 70.03 ... 190.0 190.0
#   * time                               (time) datetime64[ns] 1994-01-01T15:20:00
# Data variables: (12/17)
#     dt_analysis                        (time, lat, lon) float32 ...
#     l2p_flags                          (time, lat, lon) float32 ...
#     quality_level                      (time, lat, lon) float32 ...
#     satellite_zenith_angle             (time, lat, lon) float32 ...
#     sea_ice_fraction                   (time, lat, lon) float32 ...
#     sea_ice_fraction_dtime_from_sst    (time, lat, lon) float32 ...
#     ...                                 ...
#     sst_count                          (time, lat, lon) float32 ...
#     sst_dtime                          (time, lat, lon) float64 ...
# ...

# %%
# This is incredibly slow
data.isel(time=0).sea_surface_temperature.plot()

# %%
sst_path = "s3://imos-data-pixeldrill/zarrs/2019/"

s3 = s3fs.S3FileSystem(anon=True)
data2 = xr.open_dataset(s3fs.S3Map(sst_path, s3=s3), engine="zarr")
data2
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 333, lat: 4500, lon: 6000)
# Coordinates:
#   * lat                      (lat) float32 19.99 19.97 19.95 ... -69.97 -69.99
#   * lon                      (lon) float32 70.01 70.03 70.05 ... 190.0 190.0
#   * time                     (time) datetime64[ns] 2019-01-01T15:20:00 ... 20...
# Data variables:
#     dt_analysis              (time, lat, lon) float32 ...
#     l2p_flags                (time, lat, lon) float32 ...
#     quality_level            (time, lat, lon) float32 ...
#     satellite_zenith_angle   (time, lat, lon) float32 ...
#     sea_surface_temperature  (time, lat, lon) float32 ...
#     sses_bias                (time, lat, lon) float32 ...
#     sses_count               (time, lat, lon) float32 ...
#     sses_standard_deviation  (time, lat, lon) float32 ...
# Attributes: (12/47)
#     Conventions:                CF-1.6
#     Metadata_Conventions:       Unidata Dataset Discovery v1.0
# ...

# %%
drill = data2.isel(lat=2250, lon=3000)
# drill.sea_surface_temperature.plot(robust=True)
drill.sea_surface_temperature.values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...
